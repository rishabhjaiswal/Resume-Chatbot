# %% [markdown]
# <a href="https://colab.research.google.com/github/rishabhjaiswal/Resume-Chatbot/blob/main/experiment/ats_checker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk spacy scikit-learn

# %% [markdown]
# **clean_text** function that does these things in order:
# 1.   Lowercase everythng
# 2.   Remove punctuation and numbers
# Split text into individual words (tokenize)
# Remove common filler words like "the", "and", "is" (stopwords)
# Reduce words to their root form — "running" becomes "run"
# (lemmatization)

# %%
from os.path import join
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
def clean_text(text):
  lower_text=text.lower()
  remove_punctuation=''.join(letter for letter in lower_text if letter.isalnum() or letter.isspace()) # Allow spaces
  remove_numbers=''.join(letter for letter in remove_punctuation if not letter.isdigit())
  tokens = word_tokenize(remove_numbers)
  filtered_words = [word for word in tokens if word not in stopwords.words('english')]
  lemmatizer = WordNetLemmatizer()
  lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_words]
  return lemmatized_words

print(clean_text("The cats were running faster than the dogs."))
# Out:
# ['cat', 'running', 'faster', 'dog']

# %%
skills_list = ["Python", "ML", "LLMs", "RAG", "PyTorch", "TensorFlow", "Hugging Face", "LangChain", "Vector Databases", "MLOps", "Docker", "Kubernetes"]
my_skills = ["Machine Learning", "Deep Learning", "Python", "Large Language Models (LLMs)", "Generative AI", "Retrieval-Augmented Generation (RAG)", "Prompt Engineering", "LangChain", "LlamaIndex", "Vector Databases", "Fine-Tuning", "Hugging Face", "PyTorch", "TensorFlow", "MLOps", "Model Deployment", "Model Evaluation", "NLP (Natural Language Processing)", "SQL", "Docker / Kubernetes"]

def extract_keywords(skills):
  skills = skills.lower()
  found = [skill for skill in skills_list if skill in skills]
  return found

# result = extract_keywords(my_skills)


# print(result)

# %%
def match_keywords(job_description, skills):
  #job_description_tokens = clean_text(job_description)
  #print(job_description_tokens)
  jd_keywords = extract_keywords(job_description)
  print(jd_keywords)
  #skill_tokens = clean_text(skills)
  skill_keywords = extract_keywords(skills)

  matched_keywords = jd_keywords.intersection(skill_keywords)
  missing_keywords = skill_keywords - jd_keywords
  #percent_matched = (len(matched_keywords) / len(skill_keywords) )* 100
  return matched_keywords, missing_keywords
  #, percent_matched

# %%
jd = """The Generative AI and Intelligent Systems Engineer (KTP Associate) will hold a relevant degree. This might be a first degree (equivalent to a first class or 2:1 honours) in Computer Science, Artificial Intelligence, Data Science, Software Engineering, or a closely related discipline. A master’s degree in Artificial Intelligence, Machine Learning, Generative Ai, or a closely related field will be advantage.

Essential
A minimum 2:1 undergraduate qualification in Computer Science, Artificial Intelligence, Data Science, Software Engineering, or a closely related discipline with a First Class or 2:1 Honours degree.
Strong programming skills (Python essential).
Experience with machine learning frameworks (e.g., PyTorch, TensorFlow).
Experience with Large Language Models (LLMs) and NLP systems.
Experience designing APIs and system architectures.
Knowledge of cloud computing environments (AWS, GCP, Azure).
Experience with data modelling and ETL pipelines.
Strong analytical and problem-solving skills.
Experience working on innovation-led projects.
Ability to translate technical solutions into commercial applications.
Desirable
Master’s degree or PhD (awarded or near completion) in Artificial Intelligence, Machine Learning, Generative AI, or a closely related discipline will be an advantage.
Experience with generative AI (Diffusion models, CLIP, NeRF, 3D GANs).
Knowledge of 3D rendering (WebGL, GLTF, mesh processing).
Experience integrating Speech-to-Text systems.
Experience with multi-agent AI frameworks (e.g., LangChain).
Knowledge of Explainable AI (SHAP, LIME).
Experience with CAD/CAM systems.
Experience in manufacturing or digital commerce environments.
Publication record in AI or software engineering.
Academic acumen to enable successful reporting through research publications in academic journals and marketing/training materials.
"""

skills = """
Technical Skills: LLMs, Agentic AI, Machine Learning, RAG, Prompt Engineering, MLOps, NLP, Transformers
Languages: Python, SQL, JavaScript (ES6)
Frameworks & Libraries: LangChain, LlamaIndex, HuggingFace, FastAPI, Flask, Scikit-learn, TensorFlow, Keras, NumPy, Pandas, React JS, React Native
Databases: FAISS, Pinecone, MySQL, SQLite
DevOps & Infrastructure: Docker, Kubernetes (AKS), Azure OpenAI, CI/CD
"""

matched_keywords, missing_keywords = match_keywords(jd, skills)

print(f"Matched Keywords: {matched_keywords}")
print(f"Missing Keywords: {missing_keywords}")
#percent_matched = round(percent_matched, 2)
#print(f"Percent Matched: {percent_matched}%")
# Out:
# []
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_9227/156821229.py in <cell line: 0>()
#      33 """
#      34
# ---> 35 matched_keywords, missing_keywords = match_keywords(jd, skills)
#      36
#      37 print(f"Matched Keywords: {matched_keywords}")
#
# /tmp/ipykernel_9227/4256086722.py in match_keywords(job_description, skills)
#       7   skill_keywords = extract_keywords(skills)
#       8
# ----> 9   matched_keywords = jd_keywords.intersection(skill_keywords)
#      10   missing_keywords = skill_keywords - jd_keywords
#      11   #percent_matched = (len(matched_keywords) / len(skill_keywords) )* 100
#
# AttributeError: 'list' object has no attribute 'intersection'
